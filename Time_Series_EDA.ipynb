# %%
import pandas_datareader as pdr
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime

# %%
#pdr.get_data_yahoo('TSLA')

# %%
import yfinance as yf

# %%
df_tesla = yf.download('TSLA')
df_tesla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-04-29  188.419998  198.869995  184.539993  194.050003  194.050003
# 2024-04-30  186.979996  190.949997  182.839996  183.279999  183.279999
# 2024-05-01  182.000000  185.860001  179.009995  179.990005  179.990005
# 2024-05-02  182.860001  184.600006  176.020004  180.009995  180.009995
# 2024-05-03  182.009995  184.389999  181.439499  183.949905  183.949905
#
#                Volume
# Date
# ...

# %%
df_tesla['High'].plot(figsize = (20,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2024-05-02'],figsize = (20,4))
# Out:
# <Axes: xlabel='Date'>

# %%
##x,y limit& coloring


df_tesla['High'].plot(xlim=['2020-01-01','2024-05-02'],ylim=[0,500],figsize = (20,4),c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-04-22', '2024-04-23', '2024-04-24', '2024-04-25',
#                '2024-04-26', '2024-04-29', '2024-04-30', '2024-05-01',
#                '2024-05-02', '2024-05-03'],
#               dtype='datetime64[ns]', name='Date', length=3486, freq=None)

# %%
df_tesla.loc['2020-01-01':'2024-05-02']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2024-04-26  168.850006  172.119995  166.369995  168.289993  168.289993
# 2024-04-29  188.419998  198.869995  184.539993  194.050003  194.050003
# 2024-04-30  186.979996  190.949997  182.839996  183.279999  183.279999
# 2024-05-01  182.000000  185.860001  179.009995  179.990005  179.990005
# 2024-05-02  182.860001  184.600006  176.020004  180.009995  180.009995
#
#                Volume
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# ...

# %%
index = df_tesla.loc['2020-01-01':'2024-05-02'].index
share_open = df_tesla.loc['2020-01-01':'2024-05-02']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2024-04-26    168.850006
# 2024-04-29    188.419998
# 2024-04-30    186.979996
# 2024-05-01    182.000000
# 2024-05-02    182.860001
# Name: Open, Length: 1091, dtype: float64

# %%
figure, axis = plt.subplots(figsize=(10,4))
plt.tight_layout()
# Prevent overlapping
figure.autofmt_xdate()
axis.plot(index, share_open, linestyle='-')

plt.show()

# %%
# Date time index
